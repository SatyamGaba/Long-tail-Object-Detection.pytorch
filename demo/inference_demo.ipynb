# %%
from mmdet.apis import init_detector, inference_detector, show_result_pyplot
import mmcv
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
# config_file = '../configs/mask_rcnn/mask_rcnn_r50_fpn_1x_coco.py'
# config_file = '../configs/lvis/mask_rcnn_r50_fpn_sample1e-3_mstrain_1x_lvis_v1.py'
config_file = '../configs/custom/gs_eval.py'
# config_file = '../configs/mask_rcnn/mask_rcnn_r50_caffe_fpn_mstrain-poly_2x_coco.py'
# download the checkpoint from model zoo and put it in `checkpoints/`
# checkpoint_file = '../checkpoints/mask_rcnn_r50_caffe_fpn_mstrain-poly_2x_coco_bbox_mAP-0.403__segm_mAP-0.365_20200504_231822-a75c98ce.pth'
# checkpoint_file = '../work_dirs/mask_rcnn_r50_fpn_sample1e-3_mstrain_1x_lvis_v1/latest.pth'
checkpoint_file = '../work_dirs/gs_faster_rcnn_r50_fpn_1x_lvis_with0_bg8/transfer/epoch_2.pth'
# checkpoint_file = '../checkpoints/trained/faster_rcnn_r50_fpn_1x_lvis.pth'

# %%
# build the model from a config file and a checkpoint file
model = init_detector(config_file, checkpoint_file, device='cuda:0')
# model = init_detector(config_file, checkpoint_file, device='cpu')
# Out:
# Step 0
# Step 1
# Step 3
# Step 4
# Step 5
# Step 6

# %%
# test a single image
img = '../000000005802.jpg'
result = inference_detector(model, img)

# %%
# show the results
show_result_pyplot(model, img, result,score_thr=0.1)
